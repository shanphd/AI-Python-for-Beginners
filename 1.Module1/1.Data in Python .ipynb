# %% [markdown]
# ### Stings in Python

# %%
print (" Shan Never Give up Never allow the Problem to Defeat you" )
# Out:
#  Shan Never Give up Never allow the Problem to Defeat you

# %% [markdown]
# print("¯\_(ツ)_/¯")

# %% [markdown]
# ### Multiline Strings

# %%
print  ("""Shan you are
the best Data scientist
never give up 
        """)
# Out:
# Shan you are
# the best Data scientist
# never give up

# %% [markdown]
# ### Type Function

# %%
type ("shan")
# Out:
# str

# %%
type (3.14)
# Out:
# float

# %%
type (3)
# Out:
# int

# %% [markdown]
# ### Order of operations

# %%
print (75-35*5/9) # wrong
# Out:
# 55.55555555555556

# %%
print ((75-32) * 5/9)  # correct
# Out:
# 23.88888888888889

# %%
print (6 * 0.3038) # feet to meters
# Out:
# 1.8228

# %% [markdown]
# ## Formatted String

# %%
print (f"shan will be a great scientist in {2025+1} Years")
# Out:
# shan will be a great scientist in 2026 Years

# %%
print (f"""shan you are 
the best data scientist and wishing you all 
the best for the year {2025+1}
year when you became {35+1} year""")
# Out:
# shan you are
# the best data scientist and wishing you all
# the best for the year 2026
# year when you became 36 year

# %%
# Weight calulator 

print (f"""shan at present you are {120*2.20462} pounds 
and you will become {90*2.20462} pounds
in the year {2025+1} """ )
# Out:
# shan at present you are 264.5544 pounds
# and you will become 198.4158 pounds
# in the year 2026

# %% [markdown]
# ### Variables in Python

# %%
name = "shan"
age = 36
postion = "Data scientist"
weight = 120 * 2.20462 # pounds 

print (f"""My name is {name},
age is {age},
my position is {postion},
and my weight is {weight} in pounds,
you are gunner,
best,
wish you all the best... """)
# Out:
# My name is shan,
# age is 36,
# my position is Data scientist,
# and my weight is 264.5544 in pounds,
# you are gunner,
# best,
# wish you all the best...

# %% [markdown]
# ### Building LLM prompts with variables

# %%
from helper_functions import print_llm_response
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from helper_functions import print_llm_response
#
# File e:\2.Shan_Datascience\2.AI_Datascience\2.Python\5.AI in Python\AI-Python-for-Beginners\1.Module1\helper_functions.py:1
# ----> 1 from openai import OpenAI
#       3 client = OpenAI(
#       4   api_key="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"
#       5 )
#       7 response = client.responses.create(
#       8   model="gpt-5-nano",
#       9   input="write a haiku about ai",
#      10   store=True,
#      11 )
#
# ModuleNotFoundError: No module named 'openai'

# %%
# !pip install openai
# Out:
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 22.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------------------------- -------------- 1.3/2.0 MB 10.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 4.7 MB/s  0:00:00
# ...
#
#    --- ------------------------------------  1/13 [tqdm]
#    ------------ ---------------------------  4/13 [jiter]
#    --------------------- ------------------  7/13 [anyio]
#    --------------------- ------------------  7/13 [anyio]
#    --------------------------- ------------  9/13 [pydantic]
#    --------------------------- ------------  9/13 [pydantic]
#    --------------------------- ------------  9/13 [pydantic]
#    --------------------------- ------------  9/13 [pydantic]
#    ------------------------------ --------- 10/13 [httpcore]
#    --------------------------------- ------ 11/13 [httpx]
# ...

# %%
from helper_functions import print_llm_response
# Out:
# Silent circuits hum
# learning thoughts in quiet clocks
# stars read the data
