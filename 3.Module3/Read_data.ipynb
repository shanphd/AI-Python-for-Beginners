# %% [markdown]
# ### Read a Text file from Notebook

# %%
! pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\shanphd\appdata\local\programs\python\python313\lib\site-packages (25.2)
# Collecting pip
#   Downloading pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-25.3-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 8.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 9.7 MB/s  0:00:00
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: To modify pip, please run the following command:
# C:\Users\shanphd\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
from IPython.display import display,Markdown

# %%
f = open("Snowflake wh cost.txt","r")
sfk_wh = f.read()
f.close()
print(sfk_wh)
# Out:
# Snowflake Warehouse Costs (Example: $3/credit/hour)
#
# Warehouse Size,Credits/Hour,Cost/Hour ($)
# X-Small,1,3.0
# Small,2,6.0
# Medium,4,12.0
# Large,8,24.0
# X-Large,16,48.0
# 2X-Large,32,96.0
# 3X-Large,64,192.0
# 4X-Large,128,384.0
# 5X-Large,256,768.0
# 6X-Large,512,1536.0
#
#
# Snowflake DTC Sample: 5 x 3X-Large Warehouses
#
# Warehouse Count: 5
# Size: 3X-Large (each)
# Credits per Hour per WH: 64
# Cost per Credit: $3.00
# Total Credits/Hour (all 5): 320
# Total Cost/Hour ($): 960.00
#
# Monthly Estimate (730 hours): $700,800.00
#
# Note: Actual DTC adds egress fees (~$20-150/TB transferred).

# %%
prompt = f"""Below is the Snowflake wh sample cost list 

snowflake WH Details:
{sfk_wh}
"""

print(prompt)
# Out:
# Below is the Snowflake wh sample cost list
#
# snowflake WH Details:
# Snowflake Warehouse Costs (Example: $3/credit/hour)
#
# Warehouse Size,Credits/Hour,Cost/Hour ($)
# X-Small,1,3.0
# Small,2,6.0
# Medium,4,12.0
# Large,8,24.0
# X-Large,16,48.0
# 2X-Large,32,96.0
# 3X-Large,64,192.0
# 4X-Large,128,384.0
# 5X-Large,256,768.0
# 6X-Large,512,1536.0
#
#
# Snowflake DTC Sample: 5 x 3X-Large Warehouses
#
# Warehouse Count: 5
# Size: 3X-Large (each)
# Credits per Hour per WH: 64
# Cost per Credit: $3.00
# Total Credits/Hour (all 5): 320
# Total Cost/Hour ($): 960.00
#
# Monthly Estimate (730 hours): $700,800.00
#
# Note: Actual DTC adds egress fees (~$20-150/TB transferred).

# %%
display(Markdown(prompt))
# Out:
# Below is the Snowflake wh sample cost list
#
# snowflake WH Details:
# Snowflake Warehouse Costs (Example: $3/credit/hour)
#
# Warehouse Size,Credits/Hour,Cost/Hour ($)
# X-Small,1,3.0
# Small,2,6.0
# Medium,4,12.0
# Large,8,24.0
# X-Large,16,48.0
# 2X-Large,32,96.0
# 3X-Large,64,192.0
# 4X-Large,128,384.0
# 5X-Large,256,768.0
# 6X-Large,512,1536.0
#
#
# Snowflake DTC Sample: 5 x 3X-Large Warehouses
#
# Warehouse Count: 5
# Size: 3X-Large (each)
# Credits per Hour per WH: 64
# Cost per Credit: $3.00
# Total Credits/Hour (all 5): 320
# Total Cost/Hour ($): 960.00
#
# Monthly Estimate (730 hours): $700,800.00
#
# Note: Actual DTC adds egress fees (~$20-150/TB transferred).
